# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# common
import os
import os.path as op

# DEV: override installed teslakit
import sys
sys.path.insert(0, op.join(os.path.abspath(''), '..', '..', '..', '..'))

# teslakit
from teslakit.database import Database

# %% [markdown]
# ### Generate database - climate change: intermediate SLR scenario (S2, +1m) and future ENSO probability

# %%
# --------------------------------------
# Teslakit database

p_data = r'/media/administrador/HD/Dropbox/Guam/teslakit/data'
# p_data=r'/Users/laurac/Dropbox/Guam/teslakit/data'
db = Database(p_data)

# make new database for climate change - S4
db.MakeNewSite('GUAM_CC_S5')
# Out:
# Teslakit Site generated at /media/administrador/HD/Dropbox/Guam/teslakit/data/sites/GUAM_CC_S5
