# %% [markdown]
# ... ***CURRENTLY UNDER DEVELOPMENT*** ...

# %% [markdown]
# ## Obtain expected Sea Level Rise at the Site under 3 different scenarios based on Sweet et al. (2017)
#
#     S1 --> Intermediate Low (+0.5m)
#     S2 --> Intermediate (+1m)
#     S3 --> Intermediate high (+1.5m)
#
# inputs required:
#   * CSV file containing data for the report "Global and Regional Sea Level Rise Scenarios for the United States" (techrpt083.csv). Data are at different spatial scales:
#       - Global Mean Sea Level
#       - Tide Gauges
#       - Regional Grid
#
# in this notebook:
#   * Select projected SLR at closest Tide Gauge for the 3 scenarios
#   * Fit SLR to a 2º order polynomial from year 2000 to 2100
#   * Interpolate to hourly values
#   * Save to a netcdf file
#
#
# references:
# - Sweet, William & Kopp, Robert & Weaver, Christopher & Obeysekera, Jayantha & Horton, Radley & Thieler, E. & Zervas, Chris. (2017). GLOBAL AND REGIONAL SEA LEVEL RISE SCENARIOS FOR THE UNITED STATES.

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# common
import os
import os.path as op

# pip
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt

# DEV: override installed teslakit
import sys
sys.path.insert(0, op.join(os.path.abspath(''), '..', '..', '..'))

from teslakit.database import Database
from teslakit.io.aux_nc import StoreBugXdset

# %% [markdown]
# ## Database and Site parameters

# %%
# --------------------------------------
# Teslakit database

p_data = r'/media/administrador/HD/Dropbox/Guam/teslakit/data'
# p_data=r'/Users/laurac/Dropbox/Guam/teslakit/data'
db = Database(p_data)

# set site
db.SetSite('GUAM')

# Guam coordinates
lon = 144.75
lat = 13.44

# SLR parameters 
Scenarios = ['0.5', '1.0', '1.5']  # '0.3', '0.5', '1.0', '1.5', '2.0', '2.5'
Subscenario = 'MED'                # 'HIGH', 'MED', 'LOW'
location = 'TGs'                   # 'GMSL', 'TGS', 'RegionalGrid'

# %% [markdown]
# ## Prepare site SLR data

# %%
# ------------------------------------------------------------------------
# 1) read excel data (techrpt083.csv) and select site

p_csv = db.paths.site.CLIMATE_CHANGE.slr_csv
data = pd.read_csv(p_csv, skiprows=30)

# Global SL
if location == 'GMSL': 
    site = 'GMSL'
    data_site = data.iloc[:18]

# Regional SL
else: 
    if location == 'TGs':
        data = data.iloc[18:4302]
        
    elif location == 'RegionalGrid':
        data = data.iloc[4302:]

    # find closest point:
    dif_lon = data['Longitude'] - lon
    dif_lat = data['Latitude'] - lat
    dif = np.sqrt(dif_lon**2 + dif_lat**2)

    min_dist = dif.min(skipna=True)
    min_ind = dif.idxmin(skipna=True)

    site = data['Site'].loc[min_ind]
    data_site = data.loc[(data['Site'] == site)]

    print(site)
    print(data_site.T)
    print()
# Out:
# APRA HARBOUR
#                                      1638          1639          1640  \
# Site                         APRA HARBOUR  APRA HARBOUR  APRA HARBOUR
# PSMSL ID                              540           540           540
# Latitude                            13.44         13.44         13.44
# Longitude                          144.65        144.65        144.65
# Scenario                        0.3 - MED     0.3 - LOW    0.3 - HIGH
# Background RSL rate (mm/yr)         -0.37         -0.82          0.08
# RSL in 2000 (cm)                        0             0             0
# RSL in 2010 (cm)                        3             0             5
# RSL in 2020 (cm)                        6             1             9
# RSL in 2030 (cm)                       10             6            15
# RSL in 2040 (cm)                       15             9            20
# RSL in 2050 (cm)                       19            11            26
# RSL in 2060 (cm)                       24            14            32
# RSL in 2070 (cm)                       27            15            38
# RSL in 2080 (cm)                       30            16            44
# RSL in 2090 (cm)                       35            19            50
# RSL in 2100 (cm)                       38            19            55
# RSL in 2120 (cm)                       44            23            64
# RSL in 2150 (cm)                       51            22            75
# RSL in 2200 (cm)                       52            -1            95
#
#                                      1641          1642          1643  \
# Site                         APRA HARBOUR  APRA HARBOUR  APRA HARBOUR
# PSMSL ID                              540           540           540
# Latitude                            13.44         13.44         13.44
# Longitude                          144.65        144.65        144.65
# Scenario                        0.5 - MED     0.5 - LOW    0.5 - HIGH
# Background RSL rate (mm/yr)         -0.37         -0.82          0.08
# RSL in 2000 (cm)                        0             0             0
# RSL in 2010 (cm)                        4             1             6
# RSL in 2020 (cm)                        8             4            11
# RSL in 2030 (cm)                       13             9            17
# RSL in 2040 (cm)                       19            14            22
# RSL in 2050 (cm)                       24            18            29
# RSL in 2060 (cm)                       31            23            36
# RSL in 2070 (cm)                       35            27            43
# RSL in 2080 (cm)                       41            32            49
# RSL in 2090 (cm)                       47            38            55
# RSL in 2100 (cm)                       52            38            65
# RSL in 2120 (cm)                       61            43            78
# RSL in 2150 (cm)                       75            51            99
# RSL in 2200 (cm)                       96            49           139
#
#                                      1644          1645          1646  \
# Site                         APRA HARBOUR  APRA HARBOUR  APRA HARBOUR
# PSMSL ID                              540           540           540
# Latitude                            13.44         13.44         13.44
# Longitude                          144.65        144.65        144.65
# Scenario                        1.0 - MED     1.0 - LOW    1.0 - HIGH
# Background RSL rate (mm/yr)         -0.37         -0.82          0.08
# RSL in 2000 (cm)                        0             0             0
# RSL in 2010 (cm)                        6             2             8
# RSL in 2020 (cm)                       11             6            15
# RSL in 2030 (cm)                       19            14            24
# RSL in 2040 (cm)                       28            22            33
# RSL in 2050 (cm)                       39            31            46
# RSL in 2060 (cm)                       53            42            60
# RSL in 2070 (cm)                       67            55            77
# RSL in 2080 (cm)                       83            69            94
# RSL in 2090 (cm)                      100            85           111
# RSL in 2100 (cm)                      119           102           134
# RSL in 2120 (cm)                      147           129           164
# RSL in 2150 (cm)                      208           187           230
# RSL in 2200 (cm)                      328           286           371
#
#                                      1647          1648          1649  \
# Site                         APRA HARBOUR  APRA HARBOUR  APRA HARBOUR
# PSMSL ID                              540           540           540
# Latitude                            13.44         13.44         13.44
# Longitude                          144.65        144.65        144.65
# Scenario                        1.5 - MED     1.5 - LOW    1.5 - HIGH
# Background RSL rate (mm/yr)         -0.37         -0.82          0.08
# RSL in 2000 (cm)                        0             0             0
# RSL in 2010 (cm)                        9             4            11
# RSL in 2020 (cm)                       16             8            20
# RSL in 2030 (cm)                       26            18            30
# RSL in 2040 (cm)                       39            30            44
# RSL in 2050 (cm)                       58            45            63
# RSL in 2060 (cm)                       78            63            85
# RSL in 2070 (cm)                      101            85           111
# RSL in 2080 (cm)                      128           109           140
# RSL in 2090 (cm)                      157           136           169
# RSL in 2100 (cm)                      192           167           206
# RSL in 2120 (cm)                      245           226           266
# RSL in 2150 (cm)                      360           339           388
# RSL in 2200 (cm)                      612           564           666
#
#                                      1650          1651          1652  \
# Site                         APRA HARBOUR  APRA HARBOUR  APRA HARBOUR
# PSMSL ID                              540           540           540
# Latitude                            13.44         13.44         13.44
# Longitude                          144.65        144.65        144.65
# Scenario                        2.0 - MED     2.0 - LOW    2.0 - HIGH
# Background RSL rate (mm/yr)         -0.37         -0.82          0.08
# RSL in 2000 (cm)                        0             0             0
# RSL in 2010 (cm)                       12             9            12
# RSL in 2020 (cm)                       20            17            23
# RSL in 2030 (cm)                       33            30            37
# RSL in 2040 (cm)                       50            45            53
# RSL in 2050 (cm)                       74            69            80
# RSL in 2060 (cm)                      102            95           109
# RSL in 2070 (cm)                      134           126           145
# RSL in 2080 (cm)                      170           161           184
# RSL in 2090 (cm)                      211           201           226
# RSL in 2100 (cm)                      263           253           275
# RSL in 2120 (cm)                      352           329           362
# RSL in 2150 (cm)                      528           494           545
# RSL in 2200 (cm)                      909           840           961
#
#                                      1653          1654          1655
# Site                         APRA HARBOUR  APRA HARBOUR  APRA HARBOUR
# PSMSL ID                              540           540           540
# Latitude                            13.44         13.44         13.44
# Longitude                          144.65        144.65        144.65
# Scenario                        2.5 - MED     2.5 - LOW    2.5 - HIGH
# Background RSL rate (mm/yr)         -0.37         -0.82          0.08
# RSL in 2000 (cm)                        0             0             0
# RSL in 2010 (cm)                       12             4            13
# RSL in 2020 (cm)                       23            10            25
# RSL in 2030 (cm)                       37            24            40
# RSL in 2040 (cm)                       55            42            60
# RSL in 2050 (cm)                       86            66            90
# RSL in 2060 (cm)                      119            98           125
# RSL in 2070 (cm)                      158           136           168
# RSL in 2080 (cm)                      204           179           216
# RSL in 2090 (cm)                      254           231           267
# RSL in 2100 (cm)                      319           283           343
# RSL in 2120 (cm)                      426           411           466
# RSL in 2150 (cm)                      655           628           708
# RSL in 2200 (cm)                     1174          1107          1273

# %% [markdown]
# ## Fit SLR

# %%
# ------------------------------------------------------------------------
# 2) Fit SLR to a 2º order polynomial

# based on matlab code that Peter's group used to interpolate the 
# Sweet et al. (2017) SLR decadal projection to hourly data

time_axis = np.array(
    ['2000-01-01', '2010-01-01', '2020-01-01', '2030-01-01', '2040-01-01', '2050-01-01', '2060-01-01',
     '2070-01-01', '2080-01-01', '2090-01-01', '2100-01-01', '2120-01-01', '2150-01-01', '2200-01-01'], 
    dtype='datetime64[h]'
)
time_axis_rel = (time_axis - time_axis[0]).astype('int')

# hourly data
time_axis_H = np.arange('2000-01-01', '2101-01-01', dtype='datetime64[h]')
time_axis_H_rel = (time_axis_H - time_axis[0]).astype('int')


# prepare figure to show scenarios SLR
fig, ax = plt.subplots(1,1, figsize=(12, 9))


# solve choosen scenarios
y_fit_H = np.zeros((len(time_axis_H), len(Scenarios)))*np.nan

cont = 0
for scenario in Scenarios:
    data_subset = data_site.loc[data_site['Scenario'] == (scenario + ' - ' + Subscenario)]

    y = data_subset.to_numpy()[0][6:]
    y = y.astype('int')
    y = y/100.0  # to meters

    # Fit data, from 2000 to 2100, to a 2º polynomial function
    coef = np.polyfit(time_axis_rel[:-3], y[:-3], 2)

    # Obtain hourly data from the adjusted polynomial function
    y_temp = coef[0]*time_axis_H_rel**2 + coef[1]*time_axis_H_rel + coef[2]
    y_fit_H[:, cont] = y_temp
    cont +=1

    # plot scenario
    ax.plot(time_axis, y, '.', label='')
    ax.plot(time_axis_H, y_temp, label=scenario)

print(y_fit_H)


# set figure parameters
ax.set_xlim([time_axis[0], time_axis[-3]])
ax.set_ylim([0, 2])
ax.set_title(site + ', SL rise', fontweight='bold')
ax.set_ylabel('m')
ax.grid()
plt.legend(title='GMSL rise scenarios')

plt.show()
# Out:
# [[-0.00741411  0.00370555  0.02055926]
#  [-0.00741358  0.00370599  0.02055964]
#  [-0.00741305  0.00370643  0.02056001]
#  ...
#  [ 0.53224623  1.21280476  1.9433105 ]
#  [ 0.53224692  1.21280706  1.94331447]
#  [ 0.53224761  1.21280935  1.94331844]]

# %%
# Export SLR to netCDF4 file

# prepare SLR xarray.Dataset
SLR = xr.Dataset(
    {
        'SLR' : (('time', 'scenario'), y_fit_H)
    },
    
    coords = {
        'time' : time_axis_H,
        'scenario' : Scenarios,
    },
)
print(SLR)

# store it
p_nc = db.paths.site.CLIMATE_CHANGE.slr_nc
StoreBugXdset(SLR, p_nc)
# Out:
# <xarray.Dataset>
# Dimensions:   (scenario: 3, time: 885360)
# Coordinates:
#   * time      (time) datetime64[ns] 2000-01-01 ... 2100-12-31T23:00:00
#   * scenario  (scenario) <U3 '0.5' '1.0' '1.5'
# Data variables:
#     SLR       (time, scenario) float64 -0.007414 0.003706 ... 1.213 1.943
